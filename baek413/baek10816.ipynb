# %%
n = int(input())
n_number = list(map(int, input().split()))
m = int(input())
m_number = list(map(int, input().split()))
num_dict = {}
for i in n_number:
    if i in num_dict:
        num_dict[i] += 1
    else:
        num_dict[i] = 1
for i in m_number:
    print(num_dict.get(i, 0),end = ' ')
# Out:
# 3 0 0 1 2 0 0 2
