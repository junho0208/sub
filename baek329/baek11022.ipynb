# %%
t = int(input())
for i in range(t):
    a, b = map(int, input().split())
    print("Case #{n}:".format(n = i + 1), a, "+", b, "=", a + b)
# Out:
# Case #1: 1 + 1 = 2
# Case #2: 2 + 2 = 4
# Case #3: 3 + 3 = 6
